# %%
# Properly run external notebooks with paths wrapped in quotes. Each path includes directories with possible spaces, so must be wrapped with double quotes.
# %run "./common/spark_session"
# %run "./ingestion/ingest_orders"
# %run "./transformations/clean_orders"
# %run "./gold/sales_aggregation"

# %%
from main_pipeline import run_pipeline

run_pipeline()
